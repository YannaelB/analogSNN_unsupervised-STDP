# %%
import csv
import re
from brian2 import *
import numpy as np
from scipy.interpolate import interp1d
import brian2.numpy_ as np
import matplotlib.pyplot as plt
import time
import warnings
from random import shuffle
from tqdm.notebook import tqdm
# Out:
# INFO       Cache size for target 'cython': 1113 MB.
# You can call clear_cache('cython') to delete all files from the cache or manually delete files in the 'C:\Users\yanna\.cython\brian_extensions' directory. [brian2]

# %% [markdown]
# ## Rate Coding, single spikes

# %%
from brian2 import clear_cache
from brian2 import device
device.reinit()
start_scope()

# Simulation parameters
defaultclock.dt = 0.005*us  
seed_value = int(rand()*10)
print("seed_value = ",seed_value)



v_rest = -80*mV
v_threshold = 60*mV  
v_reset = -100*mV
v0 = -40*mV  
tau = 0.5*ms
tau2 = 15*us
Rm = 5000*Mohm
I0=1*amp
a_v = 1126.6343973469338
b_v = 169200.45773494235
x_threshold_v= 8.3e-11*amp
avoid_error = 0.01*pA
a_value = 6.23667974e13
refrac = 0*us

#dv/dt =  (v_rest - v)/tau2 +( int((I+I_exci) > firing_limit) * ((a + b * log(((I+I_exci)+ avoid_error)/firing_limit ))*I0*Rm)/ tau) : volt

avoid_error = 0.01*pA
c = 1
neuron_eqs_v1 = '''
dv/dt =  (( int((I + Ie+I_inhi) > x_threshold_v) *((a_v + b_v * log((1-int((I + Ie+I_inhi) > x_threshold_v))+int((I + Ie+I_inhi) > x_threshold_v)*(I+Ie+I_inhi+avoid_error)/(x_threshold_v) ))*I0)/a_value)*Rm) / tau : volt (unless refractory)
Ie =  activity*0.4*ge * uS *(80*mV -c*v)*inhi_factor           : amp
I_inhi =  activity*0.2*gi * uS *(-150*mV -c*v)           : amp
I : amp
dge/dt = -ge/(0.35*us)            : 1
dgi/dt = -gi/(0.5*us)            : 1
inhi_factor : 1
Rm = (5000*Mohm)*int(v<(3*(v_reset+v_threshold)/5)) + (5000*Mohm)*int(v>=(3*(v_reset+v_threshold)/5)) : ohm
activity :1
'''


V_a, V_b= 70*mV,90*mV
R_a = Rm*(V_a/mV)/(5/6)/(abs(v_threshold/mV)+abs(v_reset/mV))  #New resistance for rising till V_a
R_b = Rm*(V_b/mV)/(1/6)/(abs(v_threshold/mV)+abs(v_reset/mV)) #New resistance for rising till V_b 
neuron_eqs_v3 = '''
dv/dt =  int((I + Ie+I_inhi) > x_threshold_v) *(v_rest - v) / tau2 + (( int((I + Ie+I_inhi) > x_threshold_v) *((a_v + b_v * log((1-int((I + Ie+I_inhi) > x_threshold_v))+int((I + Ie+I_inhi) > x_threshold_v)*(I+Ie+I_inhi+avoid_error)/(x_threshold_v) ))*I0)/a_value)*Rm) / tau : volt (unless refractory)
Ie =  activity*0.4*ge * uS *(80*mV -c*v)*inhi_factor           : amp
I_inhi =  activity*0.2*gi * uS *(-150*mV -c*v)           : amp
I : amp
dge/dt = -ge/(0.35*us)            : 1
dgi/dt = -gi/(0.5*us)            : 1
inhi_factor : 1
Rm = (R_a)*int(v<(v_reset+V_a)) + (R_b)*int(v>=(v_reset+V_a)) : ohm
activity :1
'''

reset_eqs='''
v = v_reset
I=0*nA
'''

n = 1
input_group_v1 = NeuronGroup(n, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group_v1.inhi_factor = 1


input_group_v3 = NeuronGroup(n, neuron_eqs_v3, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group_v3.inhi_factor = 1


input_group_v1.v = v_reset
input_group_v3.v = v_reset
input_group_v1.I = ' 0.4*nA ' 
input_group_v3.I = ' 0.4*nA '

trace1 = StateMonitor(input_group_v1, ['v','I'], record=[0])
trace3 = StateMonitor(input_group_v3, ['v','I'], record=[0])
SP_mon1 = SpikeMonitor(input_group_v1)
SP_mon2 = SpikeMonitor(input_group_v3)


run(0.050*ms, report='text', report_period = 60*second)


print("Le nombre de spike est :", SP_mon1.count)

print("Le temps du premier spike est :", SP_mon1.t[0], "il est effectué par le neuron numéro :", SP_mon1.i[0])
print("Le temps du second spike est :", SP_mon1.t[1], "il est effectué par le neuron numéro :", SP_mon1.i[1])



# Plot the data
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1) 

plot(trace1.t/us, trace1[0].v/mV,color='r',label=f' Model Brian2 v1')
plot(trace3.t/us, trace3[0].v/mV,color='b',label=f' Model Brian2 v3')

plt.axhline(y=v_threshold/mV, color='grey', linestyle='--',label='threshold')
plt.xlabel('time us')
plt.ylabel('tension neuron mV')
plt.title('spike shape eNeuron ML')
plt.grid(True)
plt.legend()



plt.subplot(1, 2, 2) 
plot(trace1.t/us, trace1[0].I/nA,color='r',label=f' Model Brian2 v1')
plot(trace3.t/us, trace3[0].I/nA,color='b',label=f' Model Brian2 v3')
plt.xlabel('time us')
plt.ylabel('current neuron nA')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# seed_value =  5
# Starting simulation at t=0. s for a duration of 50. us
# 50. us (100%) simulated in 1s
# Le nombre de spike est : <spikemonitor.count: array([13])>
# Le temps du premier spike est : 3.73 us il est effectué par le neuron numéro : 0
# Le temps du second spike est : 7.465 us il est effectué par le neuron numéro : 0

# %% [markdown]
# ## Rate accoding to input current

# %%
from brian2 import clear_cache
from brian2 import device
device.reinit()
start_scope()

# Simulation parameters
defaultclock.dt = 0.005*us  
duration = 200*us

n = 4
input_group_v1 = NeuronGroup(n, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group_v1.inhi_factor = 1

input_group_v3 = NeuronGroup(n, neuron_eqs_v3, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group_v3.inhi_factor = 1


input_group_v1.v = v_reset
input_group_v3.v = v_reset
input_group_v1.I = [0*nA,0.15*nA,2*nA,10*nA] 
input_group_v3.I = [0*nA,0.2*nA,3*nA,10*nA]


SP_mon1 = SpikeMonitor(input_group_v1)
SP_mon3 = SpikeMonitor(input_group_v3)

run(duration, report='text', report_period = 60*second)


firing_rates1 = SP_mon1.count / duration
firing_rates3 = SP_mon3.count / duration

print(" for input_group_v1, firing rate are :",firing_rates1[0]," Hz and ", firing_rates1[1]," Hz and", firing_rates1[2]," Hz",firing_rates1[3]," Hz")
print(" for input_group_v3, firing rate are :",firing_rates3[0]," Hz and ", firing_rates3[1]," Hz and", firing_rates3[2], " Hz",firing_rates3[3]," Hz")


#check command Brian populationrate
# Out:
# Starting simulation at t=0. s for a duration of 200. us
# 200. us (100%) simulated in 4s
#  for input_group_v1, firing rate are : 0. Hz  Hz and  100. kHz  Hz and 0.54 MHz  Hz 0.81 MHz  Hz
#  for input_group_v3, firing rate are : 0. Hz  Hz and  135. kHz  Hz and 0.595 MHz  Hz 0.8 MHz  Hz

# %% [markdown]
# # Network

# %%
from brian2 import clear_cache
from brian2 import device
device.reinit()
start_scope()

n_input = 2
input_group = NeuronGroup(n_input, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group.inhi_factor = 1
input_group.activity = 1


n_hidden = 5
hidden_group = NeuronGroup(n_hidden, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
hidden_group.inhi_factor = 1
hidden_group.activity = 1


n_output = 2
output_group = NeuronGroup(n_output, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
output_group.inhi_factor = 1
output_group.activity = 1



#STDP parameters
taupre = 1*us
taupost = taupre
wmax = 1
dApre = 0.05
dApost = -dApre * taupre / taupost * 1.05

stdp_eqs = '''
    w : 1
    action : 1 (shared)
    dApre/dt = -Apre / taupre : 1 (event-driven)
    dApost/dt = -Apost / taupost : 1 (event-driven)
'''
pre_eqs='''
    ge_post += w
    Apre += dApre
    w = clip(w + action*Apost, -wmax, wmax)
'''
post_eqs='''
    Apost += dApost
    w = clip(w + action*Apre, -wmax, wmax)
'''


input_synapse = Synapses(input_group, hidden_group, model=stdp_eqs, on_pre=pre_eqs, on_post=post_eqs)
input_synapse.connect(True) # Fully connected
input_synapse.action = 0
input_synapse.w = 'rand() * wmax*0.2'
input_synapse.delay = 'rand()*0*us'


hidden_synapse = Synapses(hidden_group, output_group, model=stdp_eqs, on_pre=pre_eqs, on_post=post_eqs)
hidden_synapse.connect(True) # Fully connected
hidden_synapse.action = 0
hidden_synapse.w = 'rand() * wmax *0.4'
hidden_synapse.delay = 'rand()*0*us'


M_input = StateMonitor(input_synapse, ['w'], record=True)
M_hidden = StateMonitor(hidden_synapse, ['w'], record=True)


# Monitors for input neurons
input_spike_monitor = SpikeMonitor(input_group)
input_state_monitor = StateMonitor(input_group, ['v', 'I'], record=True)

# Monitors for input neurons
hidden_spike_monitor = SpikeMonitor(hidden_group)
hidden_state_monitor = StateMonitor(hidden_group, ['v','Ie','I_inhi'], record=True)

# Monitors for output neuron
output_spike_monitor = SpikeMonitor(output_group)
output_state_monitor = StateMonitor(output_group, ['v','Ie','I_inhi'], record=True)


print("done")
# Out:
# done

# %%
input_group.v = v_reset
input_group.I = [2*nA,0.15*nA]
input_group.v = v_reset
hidden_group.v = v_reset
output_group.v = v_reset

# Run the simulation
defaultclock.dt = 0.005*us  
duration = 100*us
run(duration, report='text', report_period = 60*second)

firing_rates1 = input_spike_monitor.count / duration
print("firing rates are :", firing_rates1," Hz" )

output_group.activity = [1,1]
input_group.I = [0*nA,0*nA]
input_group.v = v_reset
hidden_group.v = v_reset
output_group.v = v_reset

# Run the simulation
duration = 5*us
run(duration, report='text', report_period = 60*second)

firing_rates1 = input_spike_monitor.count / duration
print("firing rates are :", firing_rates1," Hz" )

input_group.I = [2*nA,2*nA]
input_group.v = v_reset
hidden_group.v = v_reset
output_group.v = v_reset

# Run the simulation
duration = 100*us
run(duration, report='text', report_period = 60*second)

firing_rates1 = input_spike_monitor.count / duration
print("firing rates are :", firing_rates1," Hz" )
# Out:
# Starting simulation at t=0. s for a duration of 100. us
# 100. us (100%) simulated in 12s
# firing rates are : [540. 100.] kHz  Hz
# Starting simulation at t=100. us for a duration of 5. us
# 5. us (100%) simulated in < 1s
# firing rates are : [10.8  2. ] MHz  Hz
# Starting simulation at t=105. us for a duration of 100. us
# 100. us (100%) simulated in 12s
# firing rates are : [1.08 0.64] MHz  Hz

# %% [markdown]
# # Input

# %%
plt.figure(figsize=(18, 8))

plt.subplot(411)
plot(input_state_monitor.t/us, input_state_monitor[0].v/mV,label='neuron n°0')
plot(input_state_monitor.t/us, input_state_monitor[1].v/mV,label='neuron n°1')
plt.axhline(y=v_threshold/mV, color='r', linestyle='--',label='threshold')
plt.legend()
title(' Voltage shape of the input neurons ')
xlabel('t (us)')
ylabel('v (mV)')

plt.subplot(412)
plot(input_state_monitor.t/us, input_state_monitor[0].I/nA,label='neuron n°0')
plot(input_state_monitor.t/us, input_state_monitor[1].I/nA,label='neuron n°1')
plt.legend()
title(' current of the input neurons ')
xlabel('t (us)')
ylabel('I (nA)')


plt.subplot(413)
for i in range(n_input*n_hidden):
    plt.plot(M_input.t/us, M_input.w[i],label=f"{i}")
plt.legend()
title(' Weight input synapse ')
xlabel('t (us)')
ylabel('W')

plt.show()

# %% [markdown]
# # Hidden

# %%
plt.figure(figsize=(22, 8))

plt.subplot(411)
for i in range(n_hidden):
    plot(hidden_state_monitor.t/us, hidden_state_monitor[i].v/mV,label=f'neuron n°{i}')
plt.axhline(y=v_threshold/mV, color='r', linestyle='--',label='threshold')
plt.legend()
title(' Voltage shape of the hidden neurons ')
xlabel('t (us)')
ylabel('v (mV)')

plt.subplot(412)
for i in range(n_hidden):
    plot(hidden_state_monitor.t/us, hidden_state_monitor[i].Ie/nA,label=f'fneuron n°{i}')
plt.legend()
title(' exci current of the hidden neurons ')
xlabel('t (us)')
ylabel('Ie (nA)')

plt.subplot(413)
for i in range(n_hidden):
    plot(hidden_state_monitor.t/us, hidden_state_monitor[i].I_inhi/nA,label=f'fneuron n°{i}')
plt.legend()
title(' Inhi current of the hidden neurons ')
xlabel('t (us)')
ylabel('I_inhi (nA)')


plt.subplot(414)
for i in range(n_output*n_hidden):
    plt.plot(M_hidden.t/us, M_hidden.w[i],label=f"{i}")
plt.legend()
title(' Weight input synapse ')
xlabel('t (us)')
ylabel('W')

plt.show()

# %% [markdown]
# # Output

# %%
plt.figure(figsize=(18, 8))

plt.subplot(411)
for i in range(n_output):
    plot(output_state_monitor.t/us, output_state_monitor[i].v/mV,label=f'neuron n°{i}')
plt.axhline(y=v_threshold/mV, color='r', linestyle='--',label='threshold')
plt.legend()
title(' Voltage shape of the output neurons ')
xlabel('t (us)')
ylabel('v (mV)')

plt.subplot(412)
for i in range(n_output):
    plot(output_state_monitor.t/us, output_state_monitor[i].Ie/nA,label=f'fneuron n°{i}')
plt.legend()
title(' exci current of the output neurons ')
xlabel('t (us)')
ylabel('Ie (nA)')

plt.subplot(413)
for i in range(n_output):
    plot(output_state_monitor.t/us, output_state_monitor[i].I_inhi/nA,label=f'fneuron n°{i}')
plt.legend()
title(' Inhi current of the output neurons ')
xlabel('t (us)')
ylabel('I_inhi (nA)')

plt.show()

# %%
plt.figure(figsize=(20, 10))
plot(input_spike_monitor.t/us, input_spike_monitor.i+np.array([-2 for i in range(len(input_spike_monitor.i))]), '*b',label='input')
plot(hidden_spike_monitor.t/us, hidden_spike_monitor.i, '*g',label='hidden')
plot(output_spike_monitor.t/us, output_spike_monitor.i+np.array([4 for i in range(len(output_spike_monitor.i))]), '*r',label='output')
plt.ylabel('Neuron index')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.subplots_adjust(right=0.75)
plt.title(" Burst map")
plt.show()

# %% [markdown]
# ## Creating XOR Data

# %%
n_train, n_test = 5,5
X_train = n_train*[[0,0]] + n_train*[[0,1]] + n_train*[[1,0]] + n_train*[[1,1]]
shuffle(X_train)
y_train = [a ^ b for a, b in X_train]

#print("X_train = ", X_train)
#print("y_train = ", y_train)

X_test = n_test*[[0,0]] + n_test*[[0,1]] + n_test*[[1,0]] + n_test*[[1,1]]
shuffle(X_test)
y_test = [a ^ b for a, b in X_test]

#print("X_test = ", X_test)
#print("y_test = ", y_test)


def from_bit_to_current(x):
    if x == [0,0]:
        return [0.15,0.15]
    elif x == [0,1]:
        return [0.15,2]
    elif x == [1,0]:
        return [2,0.15]
    elif x == [1,1]:
        return [2,2]
    else:
        print(" WARNING PROBLEM !")
        
def from_bit_to_label(x):
    if x == [0,0]:
        return 0
    elif x == [0,1]:
        return 1
    elif x == [1,0]:
        return 2
    elif x == [1,1]:
        return 3
    else:
        print(" WARNING PROBLEM !")

# %% [markdown]
# # Training Part

# %% [markdown]
#  Peu faire du STDP supervised ou j'empêche 1 des 2 output neurons de spike selon l'entrée
#  Comparer avec du random train et du genetic train
#
#  we can even imagine a learning method by making the output spiking at the desired frequency during the training.
#
# Lire papier pour savoir à quelle fréquence (ou plutot combien de temps simuler chaque epoch pour avoir un ordre de spike spike similaire aux papiers)
#
#
# !! Rajouter des contraintes sur lois synapse pour qu'elles decroissent parfois (coeff alpha 0.99 à chaque spike pre)

# %%
from brian2 import clear_cache
from brian2 import device
device.reinit()
start_scope()


input_group = NeuronGroup(n_input, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
input_group.inhi_factor = 1
input_group.activity = 1

hidden_group = NeuronGroup(n_hidden, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
hidden_group.inhi_factor = 1
hidden_group.activity = 1

output_group = NeuronGroup(n_output, neuron_eqs_v1, threshold='v >= v_threshold', reset='v = v_reset', refractory=0*us, method='heun')
output_group.inhi_factor = 1
output_group.activity = 1


input_synapse = Synapses(input_group, hidden_group, model=stdp_eqs, on_pre=pre_eqs, on_post=post_eqs)
input_synapse.connect(True) # Fully connected
input_synapse.action = 0
input_synapse.w = 'rand() * wmax * 0.2'
input_synapse.delay = 'rand()*0*us'


hidden_synapse = Synapses(hidden_group, output_group, model=stdp_eqs, on_pre=pre_eqs, on_post=post_eqs)
hidden_synapse.connect(True) # Fully connected
hidden_synapse.action = 0
hidden_synapse.w = 'rand() * wmax * 0.4'
hidden_synapse.delay = 'rand()*0*us'


# Monitors for input neurons
input_spike_monitor = SpikeMonitor(input_group)

# Monitors for input neurons
hidden_spike_monitor = SpikeMonitor(hidden_group)

# Monitors for output neuron
output_spike_monitor = SpikeMonitor(output_group)


print("done")
# Out:
# done

# %%
time_per_sample = 100 * us
resting_time = 5 * us
input_group.v = v_reset
hidden_group.v = v_reset
output_group.v = v_reset

#Create the network
net = Network(input_group, hidden_group, output_group, 
              input_synapse, hidden_synapse,
              input_spike_monitor,hidden_spike_monitor,output_spike_monitor,
             )

print(output_spike_monitor.count)
# Out:
# <spikemonitor_4.count: array([0, 0])>

# %%
weight_evol_input = []
weight_evol_hidden = []

frequency_evolution_n0 = [[],[],[],[]]
frequency_evolution_n1 = [[],[],[],[]]

time_evolution_n0 = [[],[],[],[]]
time_evolution_n1 = [[],[],[],[]]


spikes = np.zeros((4, n_output))
old_spike_counts = np.zeros(n_output)
old_spike_counts = np.copy(output_spike_monitor.count)

old_time_spikes = np.zeros(0)

tic = time.time()
for j, (sample, label) in enumerate(tqdm(zip(X_train, y_train), total=len(X_train))):


    input_group.I = from_bit_to_current(sample) * nA
    #print(" from_bit_to_current(sample) * nA = ", from_bit_to_current(sample) * nA)

    # Simuler le réseau
    net.run(time_per_sample)
    
    
    counter_spike = output_spike_monitor.count - old_spike_counts
    print("for",from_bit_to_current(sample) * nA," counter_spike = ", counter_spike)
    spikes[from_bit_to_label(sample)] += counter_spike
    # Gardons une copie du décompte de décharges pour pouvoir calculer le prochain
    old_spike_counts = np.copy(output_spike_monitor.count)
    
    rank_spike = np.copy(output_spike_monitor.i[len(old_time_spikes):])
    time_spike = np.copy(output_spike_monitor.t[len(old_time_spikes):])
    
    if rank_spike[0] == 0:
        time_evolution_n0[from_bit_to_label(sample)].append(time_spike[0])
        while rank_spike[0] != 1:
            rank_spike = rank_spike[1:]
            time_spike = time_spike[1:]
        time_evolution_n1[from_bit_to_label(sample)].append(time_spike[0])
        
    elif rank_spike[0] == 1:
        time_evolution_n1[from_bit_to_label(sample)].append(time_spike[0])
        while rank_spike[0] != 0:
            rank_spike = rank_spike[1:]
            time_spike = time_spike[1:]
        time_evolution_n0[from_bit_to_label(sample)].append(time_spike[0])
    
        
    
    frequency_evolution_n0[from_bit_to_label(sample)].append(counter_spike[0]/time_per_sample)
    frequency_evolution_n1[from_bit_to_label(sample)].append(counter_spike[1]/time_per_sample)
    
    #print(" frequency_evolution_n0 = ",frequency_evolution_n0)
    #print(" frequency_evolution_n1 = ",frequency_evolution_n1)

    # Arrêter l'entrée
    input_group.I = 0 * nA
    # Laisser les variables retourner à leurs valeurs de repos
    net.run(resting_time) ##ATTENTION, semble pas possible pour mes neurones models
    
    input_group.v = v_reset
    hidden_group.v = v_reset
    output_group.v = v_reset
    
    old_spike_counts = np.copy(output_spike_monitor.count)
    old_time_spikes = np.copy(output_spike_monitor.i)


    if j >= 4 and j<5:
        plt.figure(figsize=(20, 10)) 
        plot(input_spike_monitor.t/us, input_spike_monitor.i+np.array([-2 for i in range(len(input_spike_monitor.i))]), '.b',label='input')
        plot(output_spike_monitor.t/us, output_spike_monitor.i+np.array([4 for i in range(len(output_spike_monitor.i))]), '.g',label='output')
        plot(hidden_spike_monitor.t/us, hidden_spike_monitor.i, '.r',label='hidden')
        plt.ylabel('Neuron index')
        plt.legend()
        plt.savefig("spike_map2.png")
        plt.show()
        
        
    #NORMALISATION :
    weight_matrix = np.zeros([n_input, n_hidden])
    weight_matrix[input_synapse.i, input_synapse.j] = input_synapse.w
    sumCol = np.sum(weight_matrix, axis=0)
    colFactors = 1/sumCol
    for jj in range(n_hidden):
        weight_matrix[:,jj] *= colFactors[jj]
    #input_synapse.w = weight_matrix[input_synapse.i, input_synapse.j]

    weight_matrix = np.zeros([n_hidden, n_output])
    weight_matrix[hidden_synapse.i, hidden_synapse.j] = hidden_synapse.w
    sumCol = np.sum(weight_matrix, axis=0)
    colFactors = 1/sumCol
    for jj in range(n_output):
        weight_matrix[:,jj] *= colFactors[jj]
    #hidden_synapse.w = weight_matrix[hidden_synapse.i, hidden_synapse.j]
    
    

    #print("input_synapse.w[0] = ", input_synapse.w[0], "taille = ", len(input_synapse.w))
    #print("hidden_synapse.w[0] = ", hidden_synapse.w[0], "taille = ", len(hidden_synapse.w))
    weight = [input_synapse.w[i] for i in range(len(input_synapse.w))]
    weight_evol_input.append(weight)
    weight = [hidden_synapse.w[i] for i in range(len(hidden_synapse.w))]
    weight_evol_hidden.append(weight)



tac = time.time()
print("It has taken ", tac-tic,"s to run for the epoch ")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# for [2. 2.] nA  counter_spike =  [47 42]
# for [2. 2.] nA  counter_spike =  [47 42]
# for [2. 2.] nA  counter_spike =  [47 42]
# for [0.15 2.  ] nA  counter_spike =  [38 34]
# for [2.   0.15] nA  counter_spike =  [36 31]
# for [150. 150.] pA  counter_spike =  [8 7]
# for [0.15 2.  ] nA  counter_spike =  [38 34]
# for [150. 150.] pA  counter_spike =  [8 7]
# for [2.   0.15] nA  counter_spike =  [36 31]
# for [0.15 2.  ] nA  counter_spike =  [38 34]
# for [2. 2.] nA  counter_spike =  [47 42]
# for [2. 2.] nA  counter_spike =  [47 42]
# for [150. 150.] pA  counter_spike =  [8 7]
# for [150. 150.] pA  counter_spike =  [8 7]
# for [0.15 2.  ] nA  counter_spike =  [38 34]
# for [2.   0.15] nA  counter_spike =  [36 31]
# for [2.   0.15] nA  counter_spike =  [36 31]
# for [0.15 2.  ] nA  counter_spike =  [38 34]
# for [150. 150.] pA  counter_spike =  [8 7]
# for [2.   0.15] nA  counter_spike =  [36 31]
# It has taken  181.86111116409302 s to run for the epoch

# %%
for i in range(len(spikes)):
    if spikes[i].any() != np.zeros(len(spikes[i])).any():
        plt.plot(range(len(spikes[i])),spikes[i], label=f'label {i}')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6)) 

label_list = [[0,0],[0,1],[1,0],[1,1]]
plt.subplot(1, 2, 1)  
for i,label in enumerate(label_list):
    plt.plot(range(len(frequency_evolution_n0[i])), frequency_evolution_n0[i], label=f'{label}')  

plt.title('Spiking rate evolution output-neuron-0 ')
plt.xlabel(f' epoch  ')
plt.ylabel(' Hz ')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)  
for i,label in enumerate(label_list):
    plt.plot(range(len(frequency_evolution_n1[i])), frequency_evolution_n1[i], label=f'{label}')  

plt.title('Spiking rate evolution output-neuron-1 ')
plt.xlabel(f' epoch  ')
plt.ylabel(' Hz ')
plt.grid(True)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6)) 

label_list = [[0,0],[0,1],[1,0],[1,1]]
plt.subplot(1, 2, 1)  
for i,label in enumerate(label_list):
    subraste_time = [(i-j)*1e6 for (i,j) in zip(time_evolution_n0[i],time_evolution_n1[i])]
    plt.plot(range(len(time_evolution_n0[i])), subraste_time, label=f'{label}')  

plt.title('difference first spike temporal evolution (time n0 - time n1) ')
plt.xlabel(f' epoch  ')
plt.ylabel(' delta t (us) ')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Weight visualisation

# %%
print(" len(weight_evol_input) = ", len(weight_evol_input))
print(" len(weight_evol_input[0]) = ", len(weight_evol_input[0]))


plt.figure(figsize=(10, 6)) 

plt.subplot(1, 2, 1)  
for idx_w in range(len(weight_evol_input[0])):
    weight = [ligne[idx_w] for ligne in weight_evol_input]
    plt.plot(range(len(weight)), weight, label=f'w{idx_w}')  

plt.title('Evolution des poids synaptiques ')
plt.xlabel(f' epoch (input layer)  ')
plt.ylabel(' weight ')
plt.grid(True)
plt.legend()


plt.subplot(1, 2, 2)  
for idx_w in range(len(weight_evol_hidden[0])):
    weight = [ligne[idx_w] for ligne in weight_evol_hidden]
    plt.plot(range(len(weight)), weight, label=f'w{idx_w}')  

plt.title('Evolution des poids synaptiques ')
plt.xlabel(f' epoch (hidden layer)')
plt.ylabel(' weight ')
plt.grid(True)
plt.legend()



plt.show()
